# %%
arr=[10,80,20,60,90]
for element in arr:
    print(element)
# Out:
# 10
# 80
# 20
# 60
# 90

# %%
arr=[10,34,86,46]
arr.insert(2,30)
print(arr)
# Out:
# [10, 34, 30, 86, 46]

# %%
arr=[10,80,30,60,90]
arr.remove(30)
print(arr)
# Out:
# [10, 80, 60, 90]

# %%
arr=[10,80,30,60,90]
key=30
if key in arr:
    print("Element found")
else:
    print("Element is not found")
# Out:
# Element found

# %%
arr=[10,20,30,40,50]
arr[2]=35
print(arr)
# Out:
# [10, 20, 35, 40, 50]

# %%
arr=[10,20,30,40,50]
arr.sort()
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr = [10, 20, 90, 40, 50]
print(arr[3])
# Out:
# 40

# %%
arr=[10,80,30,60,90]
key=100
if key in arr:
    print("Element found")
else:
    print("Element is not found")
# Out:
# Element is not found
